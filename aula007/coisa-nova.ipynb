# %%
pip install pandas
# Out:
# ...
#                                               0.0/11.6 MB ? eta -:--:--
#      ----                                     1.2/11.6 MB 26.4 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 29.6 MB/s eta 0:00:01
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
i = 0

while i < len(df):
    print('nome:', df['nome'][i], '-idade:', df['idade'][i])
    i+= 1

# %%
i = 0
while i < len(df):
    if df['salario']> 6000:
        print(df.iloc[i])
    i += 1

# %%
# estrutura de repetição 03

for salario in df['salario']:
    print('salario', salario)

# %%
# estrutura de repetição 04
# nessa estrutura ele vai passar por cada coluna calculandoa  media 
for coluna in df.select_dtypes(include = ['int', 'float']):
    media = df[coluna].mean()
    print(f"a media de {coluna}: {media}")

# %%
# estrutura de repetição 05

# %%
dados = {'merda'}

# %%
# estrutura de repetição 06
# ultilizar while para calccular estatistica descritiva de coluns numericas, mas interrompendo loop quando um determinado criterio é atingido.


# media movel
soma_salario = 0
contador = 0 
i = 0

while i < len(df):
    soma_salario += df['salario'][i]
    contador += 1 
    media_salarios = soma_salario/contador
    if media_salarios > 7000:
        break
    print(media_salarios)
    i += 1

# %%
# calcular bonus para o funcionario usando função def 
#crie um prograr para calcular bonus de 10% para os funcionários, mas mostre o bonus para 
# cada funcionario. 


def calcular_bonus(salario):
    return salario * 0.1

bonus = []

for indice, linha in df.iterrows():
    bonus.append(calcular_bonus(linha['salario']))

print(f'bonus {bonus}')

# %%
# calcule a media idade e salario e retorne apneas um dataframe contendo as duas informações - ex. 8
media_idade = df['idade'].mean()
media_salarios = df['salario'].mean()

df_final = pd.concate(['media_idade', 'media_slario'])
