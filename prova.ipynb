# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
#                                               0.0/11.6 MB ? eta -:--:--
#      -                                        0.3/11.6 MB 9.6 MB/s eta 0:00:02
#      --                                       0.7/11.6 MB 8.8 MB/s eta 0:00:02
#      ---                                      1.0/11.6 MB 7.9 MB/s eta 0:00:02
#      ---                                      1.1/11.6 MB 7.5 MB/s eta 0:00:02
#      ---                                      1.1/11.6 MB 7.5 MB/s eta 0:00:02
#      ---                                      1.1/11.6 MB 4.1 MB/s eta 0:00:03
#      ----                                     1.4/11.6 MB 4.3 MB/s eta 0:00:03
#      -----                                    1.6/11.6 MB 4.5 MB/s eta 0:00:03
#      ------                                   1.8/11.6 MB 4.3 MB/s eta 0:00:03
#      ------                                   1.9/11.6 MB 4.2 MB/s eta 0:00:03
#      -------                                  2.1/11.6 MB 4.2 MB/s eta 0:00:03
#      -------                                  2.3/11.6 MB 4.5 MB/s eta 0:00:03
#      -------                                  2.3/11.6 MB 4.5 MB/s eta 0:00:03
#      -------                                  2.3/11.6 MB 4.5 MB/s eta 0:00:03
#      -------                                  2.3/11.6 MB 4.5 MB/s eta 0:00:03
#      -------                                  2.3/11.6 MB 4.5 MB/s eta 0:00:03
#      ---------                                2.6/11.6 MB 3.4 MB/s eta 0:00:03
#      ---------                                2.9/11.6 MB 3.5 MB/s eta 0:00:03
#      ----------                               3.2/11.6 MB 3.6 MB/s eta 0:00:03
#      -----------                              3.4/11.6 MB 3.7 MB/s eta 0:00:03
#      ------------                             3.6/11.6 MB 3.7 MB/s eta 0:00:03
#      -------------                            3.8/11.6 MB 3.8 MB/s eta 0:00:03
#      -------------                            3.8/11.6 MB 3.8 MB/s eta 0:00:03
#      -------------                            3.8/11.6 MB 3.8 MB/s eta 0:00:03
#      -------------                            3.8/11.6 MB 3.8 MB/s eta 0:00:03
#      -------------                            3.8/11.6 MB 3.8 MB/s eta 0:00:03
#      -------------                            4.0/11.6 MB 3.2 MB/s eta 0:00:03
#      --------------                           4.3/11.6 MB 3.3 MB/s eta 0:00:03
#      ----------------                         4.7/11.6 MB 3.5 MB/s eta 0:00:02
#      ----------------                         4.8/11.6 MB 3.4 MB/s eta 0:00:02
#      ----------------                         4.8/11.6 MB 3.3 MB/s eta 0:00:03
#      -----------------                        5.0/11.6 MB 3.3 MB/s eta 0:00:02
#      ------------------                       5.3/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       5.5/11.6 MB 3.4 MB/s eta 0:00:02
#      -------------------                      5.6/11.6 MB 2.4 MB/s eta 0:00:03
#      -------------------                      5.7/11.6 MB 2.4 MB/s eta 0:00:03
#      --------------------                     5.8/11.6 MB 2.4 MB/s eta 0:00:03
#      --------------------                     6.0/11.6 MB 2.5 MB/s eta 0:00:03
#      ---------------------                    6.1/11.6 MB 2.5 MB/s eta 0:00:03
#      ---------------------                    6.4/11.6 MB 2.5 MB/s eta 0:00:03
#      ----------------------                   6.5/11.6 MB 2.5 MB/s eta 0:00:03
#      ----------------------                   6.5/11.6 MB 2.5 MB/s eta 0:00:03
#      ----------------------                   6.5/11.6 MB 2.5 MB/s eta 0:00:03
#      ----------------------                   6.5/11.6 MB 2.5 MB/s eta 0:00:03
#      ----------------------                   6.5/11.6 MB 2.5 MB/s eta 0:00:03
#      ----------------------                   6.5/11.6 MB 2.3 MB/s eta 0:00:03
#      ----------------------                   6.7/11.6 MB 2.3 MB/s eta 0:00:03
#      -----------------------                  6.8/11.6 MB 2.3 MB/s eta 0:00:03
#      -----------------------                  6.9/11.6 MB 2.3 MB/s eta 0:00:03
#      ------------------------                 7.0/11.6 MB 2.3 MB/s eta 0:00:02
#      ------------------------                 7.3/11.6 MB 2.4 MB/s eta 0:00:02
#      --------------------------               7.6/11.6 MB 2.4 MB/s eta 0:00:02
#      --------------------------               7.7/11.6 MB 2.5 MB/s eta 0:00:02
#      --------------------------               7.7/11.6 MB 2.5 MB/s eta 0:00:02
#      --------------------------               7.7/11.6 MB 2.5 MB/s eta 0:00:02
#      --------------------------               7.7/11.6 MB 2.5 MB/s eta 0:00:02
#      --------------------------               7.7/11.6 MB 2.5 MB/s eta 0:00:02
#      ---------------------------              8.0/11.6 MB 2.4 MB/s eta 0:00:02
#      ---------------------------              8.1/11.6 MB 2.4 MB/s eta 0:00:02
#      ----------------------------             8.3/11.6 MB 2.4 MB/s eta 0:00:02
#      -----------------------------            8.6/11.6 MB 2.4 MB/s eta 0:00:02
#      ------------------------------           8.8/11.6 MB 2.5 MB/s eta 0:00:02
#      ------------------------------           9.0/11.6 MB 2.5 MB/s eta 0:00:02
#      -------------------------------          9.2/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------          9.3/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------          9.3/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------          9.3/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------          9.3/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------          9.3/11.6 MB 2.5 MB/s eta 0:00:01
#      --------------------------------         9.5/11.6 MB 2.4 MB/s eta 0:00:01
#      ---------------------------------        9.8/11.6 MB 2.4 MB/s eta 0:00:01
#      ----------------------------------       10.0/11.6 MB 2.5 MB/s eta 0:00:01
#      -----------------------------------      10.3/11.6 MB 2.5 MB/s eta 0:00:01
#      ------------------------------------     10.6/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------    10.8/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------    10.8/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------    10.8/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------    10.8/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------    10.8/11.6 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------    10.9/11.6 MB 2.4 MB/s eta 0:00:01
#      --------------------------------------   11.1/11.6 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  11.4/11.6 MB 2.4 MB/s eta 0:00:01
#      ---------------------------------------  11.6/11.6 MB 2.4 MB/s eta 0:00:01
#      ---------------------------------------  11.6/11.6 MB 2.4 MB/s eta 0:00:01
#      ---------------------------------------- 11.6/11.6 MB 2.4 MB/s eta 0:00:00
# Collecting numpy>=1.23.2 (from pandas)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.4/15.8 MB 11.6 MB/s eta 0:00:02
#      -                                        0.6/15.8 MB 7.1 MB/s eta 0:00:03
#      --                                       0.8/15.8 MB 6.4 MB/s eta 0:00:03
#      --                                       0.9/15.8 MB 5.1 MB/s eta 0:00:03
#      --                                       1.0/15.8 MB 4.3 MB/s eta 0:00:04
#      --                                       1.0/15.8 MB 4.1 MB/s eta 0:00:04
#      --                                       1.0/15.8 MB 4.1 MB/s eta 0:00:04
#      --                                       1.0/15.8 MB 4.1 MB/s eta 0:00:04
#      --                                       1.0/15.8 MB 4.1 MB/s eta 0:00:04
#      --                                       1.0/15.8 MB 4.1 MB/s eta 0:00:04
#      --                                       1.0/15.8 MB 4.1 MB/s eta 0:00:04
#      ---                                      1.2/15.8 MB 2.2 MB/s eta 0:00:07
#      ----                                     1.6/15.8 MB 2.6 MB/s eta 0:00:06
#      ----                                     2.0/15.8 MB 3.0 MB/s eta 0:00:05
#      ------                                   2.4/15.8 MB 3.4 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      ------                                   2.6/15.8 MB 3.6 MB/s eta 0:00:04
#      -------                                  2.9/15.8 MB 2.1 MB/s eta 0:00:07
#      -------                                  3.1/15.8 MB 2.2 MB/s eta 0:00:06
#      --------                                 3.5/15.8 MB 2.4 MB/s eta 0:00:06
#      ---------                                3.8/15.8 MB 2.5 MB/s eta 0:00:05
#      ----------                               4.0/15.8 MB 2.6 MB/s eta 0:00:05
#      ----------                               4.2/15.8 MB 2.6 MB/s eta 0:00:05
#      -----------                              4.6/15.8 MB 2.8 MB/s eta 0:00:05
#      ------------                             5.0/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      ------------                             5.1/15.8 MB 2.9 MB/s eta 0:00:04
#      -------------                            5.3/15.8 MB 2.2 MB/s eta 0:00:05
#      -------------                            5.5/15.8 MB 2.2 MB/s eta 0:00:05
#      --------------                           5.7/15.8 MB 2.3 MB/s eta 0:00:05
#      ---------------                          6.1/15.8 MB 2.4 MB/s eta 0:00:05
#      ----------------                         6.4/15.8 MB 2.5 MB/s eta 0:00:04
#      ----------------                         6.6/15.8 MB 2.5 MB/s eta 0:00:04
#      -----------------                        6.9/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      -----------------                        7.1/15.8 MB 2.6 MB/s eta 0:00:04
#      ------------------                       7.1/15.8 MB 2.1 MB/s eta 0:00:05
#      ------------------                       7.2/15.8 MB 2.1 MB/s eta 0:00:05
#      ------------------                       7.4/15.8 MB 2.1 MB/s eta 0:00:05
#      ------------------                       7.4/15.8 MB 2.1 MB/s eta 0:00:05
#      ------------------                       7.4/15.8 MB 2.1 MB/s eta 0:00:05
#      ------------------                       7.4/15.8 MB 2.1 MB/s eta 0:00:05
#      ------------------                       7.4/15.8 MB 2.1 MB/s eta 0:00:05
#      ------------------                       7.4/15.8 MB 2.1 MB/s eta 0:00:05
#      ------------------                       7.4/15.8 MB 2.1 MB/s eta 0:00:05
#      ------------------                       7.4/15.8 MB 2.1 MB/s eta 0:00:05
#      -------------------                      7.5/15.8 MB 1.9 MB/s eta 0:00:05
#      -------------------                      7.7/15.8 MB 2.0 MB/s eta 0:00:05
#      --------------------                     8.1/15.8 MB 2.0 MB/s eta 0:00:04
#      ---------------------                    8.4/15.8 MB 2.1 MB/s eta 0:00:04
#      ---------------------                    8.7/15.8 MB 2.1 MB/s eta 0:00:04
#      ---------------------                    8.7/15.8 MB 2.1 MB/s eta 0:00:04
#      ---------------------                    8.7/15.8 MB 2.1 MB/s eta 0:00:04
#      ----------------------                   8.7/15.8 MB 2.1 MB/s eta 0:00:04
#      ----------------------                   8.8/15.8 MB 2.1 MB/s eta 0:00:04
#      ----------------------                   9.0/15.8 MB 2.1 MB/s eta 0:00:04
#      -----------------------                  9.3/15.8 MB 2.1 MB/s eta 0:00:04
#      ------------------------                 9.6/15.8 MB 2.2 MB/s eta 0:00:03
#      -------------------------                10.1/15.8 MB 2.3 MB/s eta 0:00:03
#      -------------------------                10.2/15.8 MB 2.3 MB/s eta 0:00:03
#      -------------------------                10.2/15.8 MB 2.3 MB/s eta 0:00:03
#      -------------------------                10.2/15.8 MB 2.3 MB/s eta 0:00:03
#      -------------------------                10.2/15.8 MB 2.3 MB/s eta 0:00:03
#      -------------------------                10.2/15.8 MB 2.2 MB/s eta 0:00:03
#      --------------------------               10.5/15.8 MB 2.1 MB/s eta 0:00:03
#      ---------------------------              10.9/15.8 MB 2.1 MB/s eta 0:00:03
#      ----------------------------             11.2/15.8 MB 2.2 MB/s eta 0:00:03
#      ----------------------------             11.2/15.8 MB 2.2 MB/s eta 0:00:03
#      ----------------------------             11.3/15.8 MB 2.3 MB/s eta 0:00:02
#      ----------------------------             11.4/15.8 MB 2.3 MB/s eta 0:00:02
#      ----------------------------             11.4/15.8 MB 2.3 MB/s eta 0:00:02
#      ----------------------------             11.4/15.8 MB 2.3 MB/s eta 0:00:02
#      ----------------------------             11.4/15.8 MB 2.3 MB/s eta 0:00:02
#      ----------------------------             11.4/15.8 MB 2.3 MB/s eta 0:00:02
#      ----------------------------             11.4/15.8 MB 2.3 MB/s eta 0:00:02
#      -----------------------------            11.6/15.8 MB 2.1 MB/s eta 0:00:02
#      -----------------------------            11.8/15.8 MB 2.1 MB/s eta 0:00:02
#      ------------------------------           12.0/15.8 MB 2.1 MB/s eta 0:00:02
#      -------------------------------          12.4/15.8 MB 2.1 MB/s eta 0:00:02
#      -------------------------------          12.5/15.8 MB 2.1 MB/s eta 0:00:02
#      -------------------------------          12.6/15.8 MB 2.1 MB/s eta 0:00:02
#      --------------------------------         12.7/15.8 MB 2.1 MB/s eta 0:00:02
#      --------------------------------         12.7/15.8 MB 2.1 MB/s eta 0:00:02
#      --------------------------------         12.7/15.8 MB 2.1 MB/s eta 0:00:02
#      --------------------------------         12.7/15.8 MB 2.1 MB/s eta 0:00:02
#      --------------------------------         12.7/15.8 MB 2.0 MB/s eta 0:00:02
#      --------------------------------         13.0/15.8 MB 2.3 MB/s eta 0:00:02
#      ---------------------------------        13.2/15.8 MB 2.2 MB/s eta 0:00:02
#      ----------------------------------       13.5/15.8 MB 2.2 MB/s eta 0:00:02
#      -----------------------------------      13.9/15.8 MB 2.2 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.3 MB/s eta 0:00:01
#      -----------------------------------      14.1/15.8 MB 2.0 MB/s eta 0:00:01
#      ------------------------------------     14.3/15.8 MB 2.0 MB/s eta 0:00:01
#      -------------------------------------    14.9/15.8 MB 2.0 MB/s eta 0:00:01
#      --------------------------------------   15.3/15.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  15.7/15.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  15.8/15.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  15.8/15.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------  15.8/15.8 MB 2.3 MB/s eta 0:00:01
#      ---------------------------------------- 15.8/15.8 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python311\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#                                               0.0/505.5 kB ? eta -:--:--
#      ------------------------              337.9/505.5 kB 10.6 MB/s eta 0:00:01
#      -------------------------------------- 505.5/505.5 kB 8.0 MB/s eta 0:00:00
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#                                               0.0/345.4 kB ? eta -:--:--
#      ----------------------------------     317.4/345.4 kB 6.5 MB/s eta 0:00:01
#      -------------------------------------- 345.4/345.4 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
notas_funcionario1 = [8,7,6,-2,9]
notas_funcionario2 = [6,5,7,8,7]

# %%
notas_funcionario1 = [8, 7, 6, -2, 9]
notas_funcionario2 = [6, 5.5, 7, 8.3, 7]

df = {
    'a': [8, 7, 6, 2, 9],
    'b':[6, 5.5, 7, 8.3, 7]
}

df = pd.DataFrame(df)
df
# Out:
#    a    b
# 0  8  6.0
# 1  7  5.5
# 2  6  7.0
# 3  2  8.3
# 4  9  7.0

# %%
import pandas as pd 


def calcular_media(notas): 
    notas_validas = list(filter(lambda nota: nota >= 0, notas))
    media = sum(notas_validas) / len(notas_validas) if notas_validas else 0
    return media

media1 = calcular_media(notas_funcionario1)
media2 = calcular_media(notas_funcionario2)

print(f'Média do funcionário 1: {media1}')
print(f'Média do funcionário 2: {media2}')
# Out:
# Média do funcionário 1: 6.4
# Média do funcionário 2: 6.76

# %%
notas_funcionario1 = [8,7,6,-2,9]
notas_funcionario2 = [6,5,7,8,7]
def calcular_media_funcionario():
    notas_validas1 = list(filter(lambda x:( x > 0),notas_funcionario1)) # no enunciado ele pede para filtrar a nota negativa, por isso eu usei o x>0, pq toda nota menor que 0 ele desconsidera 
    notas_validas2 = list(filter(lambda x:(x > 0),notas_funcionario2))
    media_funcionario1 = sum(notas_validas1)/len(notas_validas1)
    media_funcionario2 = sum(notas_validas2)/len(notas_validas2)
    print("Média do funcionário 1: ", media_funcionario1)
    print("Média do funcionário 2: ", media_funcionario2)
 
calcular_media_funcionario()
# Out:
# Média do funcionário 1:  7.5
# Média do funcionário 2:  6.6

# %%
#3 
df = pd.DataFrame({
    'Texto':['O texto está agradável para passear e curtir',
             'O parque é um ótimo lugar para curtir',
             'As pessoas gostam de passear no parque com o tempo agradável']
})

def soma(dftexto):
    dftexto['Contagem'] = dftexto['Texto'].apply(lambda texto:len(texto))
    return dftexto

soma(df)
# Out:
#                                                Texto  Contagem
# 0       O texto está agradável para passear e curtir        44
# 1              O parque é um ótimo lugar para curtir        37
# 2  As pessoas gostam de passear no parque com o t...        60

# %%
# 5
contas = {'Salarios':[5000, 5500, 6000, 5800],
            'Aluguel': [1500, 1500, 1600, 1600],
            'Fornecedores': [2000, 2200, 2300, 2100]}

df_contas = pd.DataFrame(contas)

media_salarios = df_contas['Salarios'].apply(lambda x: x).mean()
media_aluguel = df_contas['Aluguel'].apply(lambda x: x).mean()
media_fornecedores = df_contas['Fornecedores'].apply(lambda x: x).mean()

print(f'Média Salarios:{media_salarios} . Média alguel {media_aluguel}. Média fornecedores {media_fornecedores}.')
# Out:
# Média Salarios: 5575.0 . Média alguel 1550.0. Média fornecedores 2150.0.

# %%
# 6

def calcular_raizes_quadradicas(a,b,c):
    discriminante = b**2 - 4 * a * c
    discr_calcu = discriminante

    calcular_x1_x2 = lambda a, b, c: (
        (-b + discr_calcu ** 0.5) / (2*a),
        (-b - discr_calcu ** 0.5) / (2*a)
    )

    return calcular_x1_x2(a,b,c)

raizes = calcular_raizes_quadradicas(1, -3, 2)
print("Raiz x1:", raizes[0])
print("Raiz x2:", raizes[1])
# Out:
# Raiz x1: 2.0
# Raiz x2: 1.0

# %%
#6
def calular_raizes_quadraticas(a,b,c):
    discriminante = b**2 - 4*a*c

    calcular_x1_x2 = lambda a, b, c: (
        (-b + discriminante**0,5) / (2*a),
        (-b - discriminante**0,5) / (2*a)
    )
    return calcular_x1_x2(a,b,c)

raizes = calular_raizes_quadraticas(1,-3,2)
print('Raiz x1:', raizes[0])
print('Raiz x2:', raizes[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 11
#       5     calcular_x1_x2 = lambda a, b, c: (
#       6         (-b + discriminante**0,5) / (2*a),
#       7         (-b - discriminante**0,5) / (2*a)
#       8     )
#       9     return calcular_x1_x2(a,b,c)
# ---> 11 raizes = calular_raizes_quadraticas(1,-3,2)
#      12 print('Raiz x1:', raizes[0])
#      13 print('Raiz x2:', raizes[1])
#
# Cell In[5], line 9, in calular_raizes_quadraticas(a, b, c)
#       3 discriminante = b**2 - 4*a*c
#       5 calcular_x1_x2 = lambda a, b, c: (
#       6     (-b + discriminante**0,5) / (2*a),
#       7     (-b - discriminante**0,5) / (2*a)
#       8 )
# ----> 9 return calcular_x1_x2(a,b,c)
#
# Cell In[5], line 6, in calular_raizes_quadraticas.<locals>.<lambda>(a, b, c)
#       2 def calular_raizes_quadraticas(a,b,c):
#       3     discriminante = b**2 - 4*a*c
#       5     calcular_x1_x2 = lambda a, b, c: (
# ----> 6         (-b + discriminante**0,5) / (2*a),
#       7         (-b - discriminante**0,5) / (2*a)
#       8     )
#       9     return calcular_x1_x2(a,b,c)
#
# TypeError: unsupported operand type(s) for /: 'tuple' and 'int'

# %%
# 4 
def simular_estoque(vendas, estoque_inicial, reposicoes):
    estoque = estoque_inicial.copy()
    for i in range(len(vendas)):
        estoque[i] -= vendas[i]  # Subtrai as vendas do estoque
        estoque[i] += reposicoes[i]  # Adiciona as reposições ao estoque
        # Aqui você pode adicionar uma função definida pelo usuário para calcular o novo nível de estoque
        # Por exemplo: estoque[i] = calcular_novo_estoque(estoque[i])
    return estoque

# Exemplo de uso da função:
vendas = [10, 15, 8, 12]
estoque_inicial = [100]
reposicoes = [5, 7, 6, 5]

estoque_final = simular_estoque(vendas, estoque_inicial, reposicoes)
print(estoque_final)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 16
#      13 estoque_inicial = [100]
#      14 reposicoes = [5, 7, 6, 5]
# ---> 16 estoque_final = simular_estoque(vendas, estoque_inicial, reposicoes)
#      17 print(estoque_final)
#
# Cell In[14], line 5, in simular_estoque(vendas, estoque_inicial, reposicoes)
#       3 estoque = estoque_inicial.copy()
#       4 for i in range(len(vendas)):
# ----> 5     estoque[i] -= vendas[i]  # Subtrai as vendas do estoque
#       6     estoque[i] += reposicoes[i]  # Adiciona as reposições ao estoque
#       7     # Aqui você pode adicionar uma função definida pelo usuário para calcular o novo nível de estoque
#       8     # Por exemplo: estoque[i] = calcular_novo_estoque(estoque[i])
#
# IndexError: list index out of range

# %%
def simular_estoque(vendas, reposicoes, estoque_inicial):
   estoque_real = estoque_inicial
   for dia, venda, reposicao in zip(range(1, len(vendas) + 1), vendas, reposicoes):
       estoque_real -= venda
       estoque_real += reposicao
       print(f"No dia {dia}:, Vendas: {venda}, Reposições: {reposicao}, Estoque atual: {estoque_real}")
   return estoque_real

vendas = [10, 8, 12]  
reposicoes = [5, 3, 4]  
estoque_inicial = 20  
estoque_final = simular_estoque(vendas, reposicoes, estoque_inicial)
print(f"Estoque final: {estoque_final}")
# Out:
# No dia 1:, Vendas: 10, Reposições: 5, Estoque atual: 15
# No dia 2:, Vendas: 8, Reposições: 3, Estoque atual: 10
# No dia 3:, Vendas: 12, Reposições: 4, Estoque atual: 2
# Estoque final: 2

# %%
from itertools import groupby
 
produto1={'nome': 'Camiseta', 'categoria': 'Roupas', 'preço': 29.99}
produto2={'nome': 'Calça', 'categoria': 'Roupas', 'preço': 49.99}
produto3={'nome': 'Tênis', 'categoria': 'Calçados', 'preço': 99.99}
produto4={'nome': 'Meia', 'categoria': 'Acessórios', 'preço': 9.99}
produto5={'nome': 'Boné', 'categoria': 'Acessórios', 'preço': 19.99}
 
produtos = [produto1,produto2,produto3,produto4,produto5]
 
agrupar = lambda x: x["categoria"]    
 
resultado = groupby(sorted(produtos, key=agrupar), agrupar)
 
 
for key, group in resultado:
    print(f"Chave: {key}")
    for value in group:
        print(f"- {value}")
# Out:
# Chave: Acessórios
# - {'nome': 'Meia', 'categoria': 'Acessórios', 'preço': 9.99}
# - {'nome': 'Boné', 'categoria': 'Acessórios', 'preço': 19.99}
# Chave: Calçados
# - {'nome': 'Tênis', 'categoria': 'Calçados', 'preço': 99.99}
# Chave: Roupas
# - {'nome': 'Camiseta', 'categoria': 'Roupas', 'preço': 29.99}
# - {'nome': 'Calça', 'categoria': 'Roupas', 'preço': 49.99}

# %%
#7
a) correta
b) correta
c) Incorreto
d) Incorreto
e) Correto
